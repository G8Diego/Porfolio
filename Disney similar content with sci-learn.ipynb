# %% [markdown]
# # Content Recommendation for Disney+
# ## by Diego Garrocho
# ---
#
# ### Project Overview
# 1. Intro
# 2. Data Wrangling
# 3. Data Cleaning
# 4. Model Selection
# 5. Model Testing
# 6. Conclusion

# %% [markdown]
# ## 1. Intro
# ---
# The aim of this project is to build a recommendation system for movies and TV shows. The recommendation system should be able to provide a list of similar movies or TV shows based on the input of a user. The recommendation system will use several features, including title, description, genres, production countries, actors, and more, to calculate similarity scores between movies or TV shows.
#
# The data used for this project comes from a publicly available dataset that includes information about movies and TV shows. The dataset contains information such as title, description, genre, production country, actors, runtime, and rating. The data is in a tabular format and stored in a CSV file.

# %% [markdown]
# ## 2. Data Wrangling
# ---
# Before building the recommendation system, several preprocessing steps are required to clean and transform the data. This includes handling missing values, tokenizing the text, removing stop words, lemmatizing the text, and transforming the data into a format that can be used by the recommendation system.

# %% [markdown]
# ### Imports and set up

# %%
import pandas as pd
import numpy as np
import sklearn as sk
import random
import seaborn as sns
import ast
import re
import nltk

# %%
credits_df = pd.read_csv(r'C:\Users\logan\Desktop\disneycont\credits.csv')
titles_df = pd.read_csv(r'C:\Users\logan\Desktop\disneycont\titles.csv')

# %%
print(credits_df.columns.values, titles_df.columns.values)
credits_df.shape, titles_df.shape
# Out:
# ['person_id' 'id' 'name' 'character' 'role'] ['id' 'title' 'type' 'description' 'release_year' 'age_certification'
#  'runtime' 'genres' 'production_countries' 'seasons' 'imdb_id'
#  'imdb_score' 'imdb_votes' 'tmdb_popularity' 'tmdb_score']
# ((30689, 5), (1854, 15))

# %%
full_df = pd.merge(titles_df, credits_df, on= ['id','id'])
full_df.head()
# Out:
#         id                   title   type  \
# 0  tm89464  Miracle on 34th Street  MOVIE
# 1  tm89464  Miracle on 34th Street  MOVIE
# 2  tm89464  Miracle on 34th Street  MOVIE
# 3  tm89464  Miracle on 34th Street  MOVIE
# 4  tm89464  Miracle on 34th Street  MOVIE
#
#                                          description  release_year  \
# 0  Kris Kringle, seemingly the embodiment of Sant...          1947
# 1  Kris Kringle, seemingly the embodiment of Sant...          1947
# 2  Kris Kringle, seemingly the embodiment of Sant...          1947
# 3  Kris Kringle, seemingly the embodiment of Sant...          1947
# 4  Kris Kringle, seemingly the embodiment of Sant...          1947
#
#   age_certification  runtime                         genres  \
# 0                 G       96  ['family', 'comedy', 'drama']
# 1                 G       96  ['family', 'comedy', 'drama']
# 2                 G       96  ['family', 'comedy', 'drama']
# 3                 G       96  ['family', 'comedy', 'drama']
# 4                 G       96  ['family', 'comedy', 'drama']
#
#   production_countries  seasons    imdb_id  imdb_score  imdb_votes  \
# 0               ['US']      NaN  tt0039628         7.9     50969.0
# 1               ['US']      NaN  tt0039628         7.9     50969.0
# 2               ['US']      NaN  tt0039628         7.9     50969.0
# 3               ['US']      NaN  tt0039628         7.9     50969.0
# 4               ['US']      NaN  tt0039628         7.9     50969.0
#
#    tmdb_popularity  tmdb_score  person_id            name         character  \
# 0           23.515       7.388      35549  Maureen O'Hara      Doris Walker
# 1           23.515       7.388      57832      John Payne       Fred Gailey
# 2           23.515       7.388      57833    Edmund Gwenn      Kris Kringle
# 3           23.515       7.388      25096    Natalie Wood      Susan Walker
# 4           23.515       7.388      27185     Porter Hall  Granville Sawyer
#
#     role
# 0  ACTOR
# 1  ACTOR
# 2  ACTOR
# 3  ACTOR
# 4  ACTOR

# %%
full_df.info()
print('_'*99)
full_df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30689 entries, 0 to 30688
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    30689 non-null  object
#  1   title                 30689 non-null  object
#  2   type                  30689 non-null  object
#  3   description           30686 non-null  object
#  4   release_year          30689 non-null  int64
#  5   age_certification     27498 non-null  object
#  6   runtime               30689 non-null  int64
#  7   genres                30689 non-null  object
#  8   production_countries  30689 non-null  object
#  9   seasons               2379 non-null   float64
#  10  imdb_id               26878 non-null  object
#  11  imdb_score            26712 non-null  float64
#  12  imdb_votes            26581 non-null  float64
#  13  tmdb_popularity       30689 non-null  float64
#  14  tmdb_score            30407 non-null  float64
#  15  person_id             30689 non-null  int64
#  16  name                  30689 non-null  object
#  17  character             28794 non-null  object
#  18  role                  30689 non-null  object
# dtypes: float64(5), int64(3), object(11)
# memory usage: 4.7+ MB
# ___________________________________________________________________________________________________
#        release_year       runtime      seasons    imdb_score    imdb_votes  \
# count  30689.000000  30689.000000  2379.000000  26712.000000  2.658100e+04
# mean    2005.619636     91.208413     2.770912      6.628036  2.013622e+05
# std       16.666517     35.892204     3.101734      1.024169  3.082637e+05
# min     1928.000000      2.000000     1.000000      1.600000  5.000000e+00
# 25%     2000.000000     80.000000     1.000000      6.000000  5.525000e+03
# 50%     2010.000000     96.000000     2.000000      6.700000  4.726000e+04
# 75%     2017.000000    113.000000     3.000000      7.300000  2.690350e+05
# max     2023.000000    182.000000    36.000000      9.500000  1.403757e+06
#
#        tmdb_popularity    tmdb_score     person_id
# count     30689.000000  30407.000000  3.068900e+04
# mean         48.316732      6.780725  3.985504e+05
# std         125.831614      0.878787  6.339795e+05
# min           0.600000      2.000000  4.500000e+01
# 25%          10.052000      6.273000  1.283400e+04
# 50%          20.771000      6.802000  5.797400e+04
# 75%          52.384000      7.352000  5.987110e+05
# max        2159.377000     10.000000  2.770632e+06

# %%
full_df.describe(include=['O'])
# Out:
#              id      title   type  \
# count     30689      30689  30689
# unique     1733       1695      2
# top     tm84668  Enchanted  MOVIE
# freq        245        245  28310
#
#                                               description age_certification  \
# count                                               30686             27498
# unique                                               1730                11
# top     The beautiful princess Giselle is banished by ...                PG
# freq                                                  245             11439
#
#                    genres production_countries    imdb_id          name  \
# count               30689                30689      26878         30689
# unique                700                   84       1295         19851
# top     ['documentation']               ['US']  tt0461770  Jim Cummings
# freq                 1778                26039        245            61
#
#        character   role
# count      28794  30689
# unique     18235      2
# top         Self  ACTOR
# freq        1209  29122

# %% [markdown]
# ### Initial notes
# ---
# After initial observation, there appears to be some columns that are not complete which is understandable since the dataset includes movies and tv shows combined. There also appears to be that the information obtained from imdb and tmdb has the most null values that may impact the usability of it, therefore, it might be more negative than positive to use them. In addition, other values (ids, descriptions) hold no relevance for the objetive of the project and should not be taken into consideration. Some features could still be transformed for easier use and others could be mixed and still have to check for typos. The column genres appears to have many unique values which should be looked into.
# Given the nature of the information available for the project, taking on a content-based filtering approach would be the best suited option to choose.

# %%
full_df['genres'].unique()
# Out:
# array(["['family', 'comedy', 'drama']",
#        "['horror', 'fantasy', 'animation', 'family', 'comedy']",
#        "['fantasy', 'animation', 'family', 'romance']",
#        "['animation', 'drama', 'family', 'fantasy']",
#        "['animation', 'family', 'fantasy', 'music']",
#        "['animation', 'drama', 'family']",
#        "['fantasy', 'animation', 'romance', 'family', 'thriller', 'drama']",
#        "['animation', 'documentation']", "['comedy']",
#        "['family', 'action']",
#        "['animation', 'family', 'fantasy', 'comedy']", "['animation']",
#        "['animation', 'romance', 'comedy', 'family', 'fantasy']",
#        "['animation', 'comedy', 'family']",
#        "['animation', 'comedy', 'family', 'fantasy']",
#        "['animation', 'music', 'comedy', 'family']", "['thriller']",
#        "['fantasy', 'animation']", "['comedy', 'family', 'animation']",
#        "['animation', 'family']", "['romance', 'animation']",
#        "['action', 'family']", "['documentation']",
#        "['action', 'scifi', 'fantasy']", "['romance', 'drama', 'family']",
#        "['comedy', 'animation', 'family', 'fantasy']",
#        "['comedy', 'family', 'music']", "['fantasy', 'comedy', 'family']",
#        "['action', 'drama', 'comedy', 'family', 'western']",
#        "['comedy', 'family']", "['fantasy', 'family', 'romance']",
#        "['documentation', 'family']", "['comedy', 'romance']",
#        "['romance', 'comedy', 'fantasy', 'animation', 'family', 'european']",
#        "['crime', 'action', 'comedy', 'drama', 'family']",
#        "['family', 'animation', 'action', 'fantasy', 'comedy']",
#        "['western', 'drama', 'romance', 'comedy']",
#        "['animation', 'family', 'romance', 'comedy']",
#        "['action', 'scifi']", "['comedy', 'drama', 'scifi', 'family']",
#        "['comedy', 'family', 'fantasy']",
#        "['comedy', 'animation', 'family']",
#        "['romance', 'animation', 'comedy', 'family', 'drama']",
#        "['animation', 'family', 'fantasy']",
#        "['comedy', 'romance', 'family', 'fantasy']",
#        "['family', 'documentation']",
#        "['fantasy', 'family', 'animation', 'action', 'comedy']",
#        "['comedy', 'drama', 'family', 'romance']",
#        "['comedy', 'family', 'fantasy', 'romance', 'sport', 'crime', 'action']",
#        "['action', 'drama', 'family', 'fantasy', 'scifi']",
#        "['animation', 'family', 'fantasy', 'action', 'comedy']", '[]',
#        "['drama', 'comedy', 'family']",
#        "['animation', 'family', 'comedy']",
#        "['action', 'scifi', 'family', 'fantasy']",
#        "['comedy', 'western', 'family']",
#        "['comedy', 'family', 'romance']", "['scifi']",
#        "['action', 'fantasy', 'scifi', 'family']",
#        "['thriller', 'romance', 'family']",
#        "['animation', 'family', 'fantasy', 'action']",
#        "['comedy', 'family', 'sport']", "['comedy', 'fantasy', 'family']",
#        "['family', 'action', 'drama', 'comedy']",
#        "['western', 'family', 'drama']",
#        "['fantasy', 'family', 'romance', 'comedy']",
#        "['comedy', 'family', 'scifi']",
#        "['comedy', 'european', 'family', 'fantasy']",
#        "['comedy', 'scifi', 'sport', 'family']",
#        "['western', 'drama', 'family']",
#        "['comedy', 'drama', 'crime', 'family', 'thriller']",
#        "['comedy', 'drama', 'family']",
#        "['western', 'comedy', 'drama', 'family']",
#        "['western', 'comedy', 'family']",
#        "['western', 'drama', 'family', 'romance']", "['drama', 'family']",
#        "['scifi', 'family', 'comedy', 'fantasy']",
#        "['western', 'family']",
#        "['drama', 'family', 'romance', 'western', 'action', 'comedy']",
#        "['family', 'documentation', 'action']",
#        "['fantasy', 'romance', 'family']", "['family']",
#        "['fantasy', 'comedy', 'family', 'horror']",
#        "['family', 'drama', 'action']", "['drama']",
#        "['history', 'family', 'documentation']",
#        "['animation', 'comedy']",
#        "['fantasy', 'romance', 'comedy', 'family']",
#        "['drama', 'comedy', 'fantasy', 'romance']",
#        "['comedy', 'crime', 'family', 'fantasy', 'animation']",
#        "['fantasy', 'action', 'drama', 'romance']",
#        "['comedy', 'reality', 'family']",
#        "['animation', 'fantasy', 'comedy']",
#        "['animation', 'crime', 'action', 'comedy', 'fantasy', 'scifi', 'family']",
#        "['fantasy', 'action', 'family', 'horror']",
#        "['comedy', 'crime', 'drama', 'thriller']",
#        "['action', 'family', 'scifi', 'comedy']",
#        "['comedy', 'romance', 'crime']",
#        "['scifi', 'action', 'fantasy', 'animation', 'family', 'comedy']",
#        "['animation', 'fantasy', 'comedy', 'family', 'romance']",
#        "['fantasy', 'family', 'drama', 'animation', 'comedy', 'crime', 'action']",
#        "['comedy', 'fantasy', 'romance']",
#        "['animation', 'family', 'fantasy', 'horror', 'action']",
#        "['comedy', 'crime', 'family']",
#        "['action', 'scifi', 'animation', 'comedy', 'family']",
#        "['family', 'fantasy', 'animation']",
#        "['action', 'animation', 'family', 'scifi', 'comedy', 'crime']",
#        "['scifi', 'fantasy', 'family']",
#        "['scifi', 'action', 'animation', 'family', 'fantasy']",
#        "['fantasy', 'family']", "['thriller', 'animation', 'family']",
#        "['action', 'animation', 'drama', 'family']",
#        "['fantasy', 'animation', 'comedy', 'family', 'european']",
#        "['comedy', 'romance', 'drama', 'family']",
#        "['fantasy', 'family', 'drama', 'crime', 'animation', 'comedy']",
#        "['comedy', 'family', 'fantasy', 'animation']",
#        "['family', 'fantasy', 'scifi', 'animation', 'action']",
#        "['crime']", "['horror', 'comedy']",
#        "['horror', 'drama', 'comedy', 'family']", "['family', 'drama']",
#        "['family', 'action', 'european']",
#        "['drama', 'romance', 'comedy']",
#        "['fantasy', 'animation', 'family']",
#        "['romance', 'comedy', 'drama']",
#        "['drama', 'comedy', 'family', 'romance']",
#        "['drama', 'fantasy', 'family']",
#        "['scifi', 'action', 'animation', 'family', 'thriller']",
#        "['fantasy', 'comedy', 'family', 'horror', 'european']",
#        "['fantasy', 'drama', 'comedy', 'family']",
#        "['drama', 'animation', 'family']", "['drama', 'sport']",
#        "['comedy', 'fantasy', 'animation', 'family']",
#        "['comedy', 'drama', 'romance']",
#        "['scifi', 'comedy', 'family', 'fantasy']",
#        "['drama', 'family', 'comedy']",
#        "['drama', 'sport', 'comedy', 'family', 'history', 'european']",
#        "['scifi', 'action', 'romance', 'animation', 'family', 'crime', 'thriller', 'fantasy', 'comedy', 'drama']",
#        "['family', 'comedy', 'action', 'crime']",
#        "['comedy', 'romance', 'family']",
#        "['action', 'fantasy', 'family', 'animation', 'thriller', 'crime', 'drama', 'scifi', 'romance']",
#        "['scifi', 'action', 'fantasy']", "['family', 'drama', 'music']",
#        "['action', 'comedy', 'family', 'romance']",
#        "['action', 'drama', 'scifi', 'comedy', 'family', 'sport', 'animation']",
#        "['animation', 'comedy', 'family', 'fantasy', 'war', 'drama']",
#        "['comedy', 'family', 'romance', 'animation']",
#        "['romance', 'animation', 'comedy', 'family', 'fantasy']",
#        "['animation', 'scifi', 'action', 'thriller', 'drama', 'fantasy', 'romance']",
#        "['drama', 'romance', 'animation', 'family']",
#        "['action', 'family', 'scifi']",
#        "['action', 'drama', 'fantasy', 'scifi', 'animation']",
#        "['drama', 'comedy', 'family', 'sport']",
#        "['family', 'action', 'animation', 'drama', 'comedy', 'music', 'romance']",
#        "['comedy', 'romance', 'animation', 'family', 'fantasy', 'action', 'european']",
#        "['romance', 'family', 'fantasy']",
#        "['action', 'animation', 'family', 'romance', 'drama', 'european']",
#        "['comedy', 'animation', 'documentation', 'drama', 'family', 'fantasy']",
#        "['comedy', 'family', 'music', 'crime']",
#        "['animation', 'comedy', 'drama', 'family', 'fantasy']",
#        "['comedy', 'family', 'scifi', 'action']",
#        "['music', 'family', 'action', 'romance', 'comedy']",
#        "['drama', 'family', 'history']",
#        "['fantasy', 'animation', 'family', 'scifi', 'drama', 'romance']",
#        "['comedy', 'drama', 'sport', 'family']",
#        "['comedy', 'family', 'crime']",
#        "['comedy', 'drama', 'family', 'fantasy', 'romance', 'animation']",
#        "['family', 'comedy']", "['action', 'animation', 'family']",
#        "['drama', 'family', 'romance']", "['comedy', 'scifi', 'family']",
#        "['music', 'animation', 'family', 'fantasy', 'comedy']",
#        "['action', 'animation', 'family', 'scifi', 'comedy', 'crime', 'fantasy']",
#        "['comedy', 'drama', 'fantasy']",
#        "['scifi', 'thriller', 'family']",
#        "['action', 'scifi', 'family', 'animation']",
#        "['horror', 'comedy', 'family', 'fantasy']",
#        "['family', 'action', 'animation']",
#        "['comedy', 'drama', 'family', 'animation']",
#        "['action', 'animation', 'crime', 'family', 'scifi', 'thriller']",
#        "['action', 'thriller', 'family', 'fantasy', 'european']",
#        "['comedy', 'european']",
#        "['action', 'drama', 'family', 'animation']",
#        "['animation', 'comedy', 'family', 'fantasy', 'scifi']",
#        "['action', 'comedy', 'drama', 'family', 'war']",
#        "['comedy', 'fantasy', 'family', 'animation', 'scifi', 'music']",
#        "['family', 'animation', 'fantasy', 'comedy', 'thriller', 'drama']",
#        "['family', 'sport']", "['family', 'comedy', 'crime']",
#        "['action', 'comedy', 'family', 'sport']",
#        "['romance', 'family', 'action', 'animation']",
#        "['family', 'drama', 'sport']", "['animation', 'european']",
#        "['drama', 'comedy', 'family', 'sport', 'action']",
#        "['family', 'animation', 'comedy']",
#        "['comedy', 'crime', 'family', 'scifi', 'action']",
#        "['comedy', 'family', 'action', 'crime']",
#        "['family', 'scifi', 'action', 'comedy', 'romance']",
#        "['scifi', 'fantasy', 'family', 'romance', 'comedy']",
#        "['action', 'scifi', 'family', 'thriller', 'animation']",
#        "['romance']", "['action', 'comedy', 'family', 'animation']",
#        "['family', 'comedy', 'animation', 'action']",
#        "['comedy', 'drama', 'family', 'scifi']",
#        "['comedy', 'family', 'european']",
#        "['family', 'action', 'drama']",
#        "['action', 'animation', 'scifi']",
#        "['action', 'comedy', 'family', 'fantasy', 'animation']",
#        "['animation', 'family', 'comedy', 'drama']",
#        "['animation', 'thriller', 'comedy', 'fantasy', 'action', 'crime', 'family', 'scifi', 'western']",
#        "['drama', 'romance', 'western', 'comedy', 'family']",
#        "['family', 'comedy', 'animation', 'drama', 'fantasy', 'scifi']",
#        "['comedy', 'horror', 'family', 'fantasy']",
#        "['drama', 'family', 'sport']", "['western', 'family', 'fantasy']",
#        "['animation', 'action', 'scifi']",
#        "['action', 'thriller', 'horror', 'comedy', 'family']",
#        "['action', 'drama', 'family']",
#        "['action', 'family', 'fantasy', 'scifi', 'comedy']",
#        "['drama', 'comedy', 'family', 'scifi']",
#        "['comedy', 'drama', 'documentation', 'romance', 'scifi', 'family']",
#        "['drama', 'comedy', 'sport', 'family']",
#        "['family', 'fantasy', 'music', 'comedy', 'sport', 'documentation']",
#        "['action', 'fantasy', 'scifi']",
#        "['action', 'scifi', 'animation', 'drama', 'fantasy']",
#        "['action', 'drama', 'crime', 'scifi', 'thriller']",
#        "['comedy', 'drama', 'music']",
#        "['animation', 'scifi', 'romance', 'fantasy', 'family']",
#        "['action', 'fantasy']",
#        "['action', 'thriller', 'family', 'western']",
#        "['fantasy', 'animation', 'comedy', 'family', 'drama']",
#        "['comedy', 'animation', 'drama', 'family']",
#        "['scifi', 'action']",
#        "['drama', 'european', 'music', 'animation', 'fantasy', 'thriller', 'family', 'comedy']",
#        "['music', 'reality', 'family']",
#        "['action', 'drama', 'family', 'fantasy']",
#        "['comedy', 'documentation', 'romance', 'animation', 'family', 'fantasy']",
#        "['comedy', 'family', 'music', 'reality']",
#        "['drama', 'sport', 'history', 'european']", "['reality']",
#        "['comedy', 'family', 'animation', 'fantasy']",
#        "['family', 'fantasy', 'action', 'comedy']",
#        "['fantasy', 'family', 'comedy']",
#        "['comedy', 'scifi', 'family', 'action', 'animation']",
#        "['action', 'comedy', 'family', 'scifi', 'animation']",
#        "['drama', 'comedy']", "['thriller', 'action', 'family']",
#        "['action', 'scifi', 'drama', 'family', 'fantasy', 'animation']",
#        "['drama', 'romance', 'comedy', 'sport', 'european']",
#        "['action', 'thriller', 'fantasy', 'scifi', 'family', 'horror']",
#        "['scifi', 'action', 'european']",
#        "['animation', 'fantasy', 'scifi', 'family']",
#        "['family', 'documentation', 'drama', 'european']",
#        "['action', 'music', 'scifi', 'fantasy', 'european']",
#        "['documentation', 'history']", "['action', 'thriller', 'scifi']",
#        "['drama', 'sport', 'history']", "['drama', 'comedy', 'romance']",
#        "['fantasy', 'action']",
#        "['scifi', 'action', 'fantasy', 'family']",
#        "['action', 'fantasy', 'family']",
#        "['action', 'scifi', 'animation', 'drama', 'thriller', 'crime']",
#        "['drama', 'comedy', 'romance', 'music']",
#        "['thriller', 'comedy', 'family', 'fantasy', 'horror']",
#        "['fantasy', 'action', 'family', 'european']",
#        "['drama', 'family', 'comedy', 'crime']",
#        "['comedy', 'animation']",
#        "['comedy', 'animation', 'family', 'sport']",
#        "['romance', 'comedy', 'drama', 'family']",
#        "['comedy', 'action', 'family', 'scifi']",
#        "['family', 'fantasy', 'action']",
#        "['scifi', 'action', 'animation', 'family']",
#        "['action', 'scifi', 'thriller']",
#        "['comedy', 'documentation', 'family', 'music']",
#        "['action', 'scifi', 'family', 'fantasy', 'animation']",
#        "['animation', 'fantasy', 'family', 'comedy']",
#        "['animation', 'drama', 'family', 'fantasy', 'scifi', 'comedy']",
#        "['action', 'comedy', 'family', 'romance', 'scifi', 'animation']",
#        "['animation', 'scifi', 'drama', 'comedy', 'family', 'music']",
#        "['comedy', 'crime', 'drama', 'family']",
#        "['scifi', 'action', 'family', 'fantasy', 'animation']",
#        "['comedy', 'family', 'action', 'drama']",
#        "['comedy', 'fantasy', 'animation', 'crime', 'drama', 'family', 'scifi']",
#        "['animation', 'comedy', 'family', 'fantasy', 'romance']",
#        "['romance', 'comedy', 'animation', 'fantasy', 'family', 'drama']",
#        "['comedy', 'scifi', 'fantasy', 'drama', 'family']",
#        "['romance', 'comedy', 'family', 'action', 'thriller', 'animation', 'drama']",
#        "['fantasy', 'thriller', 'action', 'family', 'scifi']",
#        "['action', 'animation', 'comedy', 'family', 'fantasy']",
#        "['comedy', 'drama', 'family', 'action']",
#        "['comedy', 'scifi', 'action', 'family', 'fantasy', 'horror']",
#        "['animation', 'fantasy', 'comedy', 'family', 'music']",
#        "['fantasy', 'action', 'scifi']",
#        "['animation', 'family', 'comedy', 'fantasy']",
#        "['comedy', 'drama', 'family', 'music']",
#        "['comedy', 'drama', 'music', 'romance', 'family']",
#        "['drama', 'family', 'music', 'romance', 'comedy']",
#        "['documentation', 'drama', 'history']",
#        "['comedy', 'scifi', 'fantasy', 'family']",
#        "['animation', 'action', 'fantasy', 'scifi', 'comedy', 'family']",
#        "['drama', 'romance', 'music']",
#        "['comedy', 'fantasy', 'sport', 'drama', 'family']",
#        "['action', 'western', 'comedy', 'family']",
#        "['fantasy', 'family', 'music', 'romance', 'comedy']",
#        "['fantasy', 'scifi', 'comedy', 'family', 'romance']",
#        "['animation', 'scifi', 'action', 'family', 'fantasy']",
#        "['comedy', 'drama', 'family', 'fantasy']",
#        "['animation', 'action', 'drama', 'family', 'scifi']",
#        "['comedy', 'family', 'drama', 'animation', 'music', 'scifi', 'fantasy']",
#        "['comedy', 'family', 'music', 'romance']",
#        "['scifi', 'fantasy', 'documentation', 'family', 'action', 'comedy']",
#        "['action', 'family', 'scifi', 'animation', 'comedy']",
#        "['comedy', 'drama', 'family', 'romance', 'sport', 'action']",
#        "['comedy', 'romance', 'drama', 'family', 'music']",
#        "['comedy', 'action', 'scifi', 'family', 'animation']",
#        "['comedy', 'family', 'fantasy', 'scifi', 'animation']",
#        "['family', 'action', 'fantasy', 'animation']",
#        "['action', 'comedy', 'drama', 'family']",
#        "['comedy', 'family', 'war', 'animation']",
#        "['family', 'action', 'comedy', 'music']",
#        "['drama', 'comedy', 'family', 'fantasy', 'animation', 'action']",
#        "['comedy', 'drama', 'romance', 'family', 'music']",
#        "['music', 'documentation']",
#        "['drama', 'romance', 'comedy', 'family', 'music', 'animation']",
#        "['family', 'action', 'animation', 'comedy', 'drama', 'fantasy']",
#        "['fantasy', 'drama', 'family']",
#        "['animation', 'family', 'comedy', 'western', 'music']",
#        "['action', 'fantasy', 'animation', 'family']",
#        "['romance', 'comedy', 'family', 'fantasy', 'sport']",
#        "['animation', 'family', 'action']",
#        "['scifi', 'comedy', 'family']", "['comedy', 'family', 'action']",
#        "['animation', 'fantasy', 'comedy', 'drama', 'family', 'music']",
#        "['animation', 'scifi']",
#        "['animation', 'family', 'comedy', 'drama', 'fantasy']",
#        "['animation', 'comedy', 'fantasy', 'family']",
#        "['comedy', 'fantasy', 'scifi', 'animation', 'action', 'family']",
#        "['drama', 'family', 'fantasy', 'horror', 'thriller']",
#        "['action', 'family', 'scifi', 'animation']",
#        "['comedy', 'romance', 'family', 'music', 'european']",
#        "['drama', 'family', 'fantasy', 'romance']",
#        "['animation', 'action', 'family']",
#        "['animation', 'comedy', 'family', 'scifi']",
#        "['comedy', 'romance', 'drama', 'family', 'sport']",
#        "['comedy', 'action', 'family', 'sport']",
#        "['animation', 'drama']",
#        "['family', 'action', 'comedy', 'sport']",
#        "['action', 'comedy', 'thriller', 'animation', 'family']",
#        "['documentation', 'sport', 'drama']", "['animation', 'fantasy']",
#        "['fantasy', 'family', 'comedy', 'sport']",
#        "['action', 'scifi', 'fantasy', 'comedy', 'family']",
#        "['comedy', 'drama', 'music', 'family']", "['comedy', 'horror']",
#        "['documentation', 'music']", "['documentation', 'scifi']",
#        "['documentation', 'european']",
#        "['drama', 'action', 'family', 'animation']",
#        "['comedy', 'romance', 'family', 'music']",
#        "['action', 'fantasy', 'romance', 'scifi', 'family']",
#        "['family', 'comedy', 'drama', 'music', 'war', 'animation', 'romance']",
#        "['comedy', 'drama']",
#        "['comedy', 'family', 'romance', 'scifi', 'thriller']",
#        "['family', 'romance', 'sport']",
#        "['drama', 'comedy', 'animation', 'family', 'romance']",
#        "['action', 'comedy', 'crime', 'family']",
#        "['comedy', 'animation', 'family', 'fantasy', 'scifi']",
#        "['animation', 'western', 'comedy', 'family', 'fantasy']",
#        "['drama', 'family', 'sport', 'comedy']",
#        "['music', 'documentation', 'family']",
#        "['action', 'family', 'fantasy', 'scifi', 'animation', 'comedy']",
#        "['comedy', 'action', 'family', 'scifi', 'drama']",
#        "['drama', 'animation', 'scifi', 'comedy', 'family', 'fantasy', 'music']",
#        "['comedy', 'family', 'scifi', 'fantasy', 'music']",
#        "['drama', 'romance', 'family']",
#        "['comedy', 'family', 'fantasy', 'drama']",
#        "['comedy', 'family', 'drama']", "['family', 'scifi', 'comedy']",
#        "['scifi', 'family', 'fantasy', 'animation', 'comedy', 'thriller', 'drama', 'horror', 'action']",
#        "['scifi', 'drama', 'fantasy', 'romance']",
#        "['action', 'family', 'comedy', 'drama']",
#        "['animation', 'scifi', 'thriller', 'comedy', 'drama', 'family', 'horror']",
#        "['action', 'scifi', 'european']",
#        "['action', 'animation', 'family', 'scifi']",
#        "['drama', 'comedy', 'crime', 'romance']",
#        "['animation', 'comedy', 'family', 'music', 'crime', 'drama']",
#        "['reality', 'action']", "['fantasy', 'scifi', 'action']",
#        "['documentation', 'reality', 'comedy', 'drama', 'family']",
#        "['scifi', 'fantasy']",
#        "['action', 'comedy', 'scifi', 'family', 'fantasy', 'animation']",
#        "['action', 'animation', 'comedy', 'family', 'scifi']",
#        "['music', 'romance', 'comedy', 'drama', 'family']",
#        "['comedy', 'animation', 'family', 'sport', 'scifi', 'drama', 'fantasy', 'crime']",
#        "['drama', 'action', 'history', 'war']",
#        "['reality', 'documentation']",
#        "['animation', 'comedy', 'drama', 'family', 'fantasy', 'european']",
#        "['action']",
#        "['comedy', 'fantasy', 'drama', 'animation', 'family']",
#        "['romance', 'drama', 'family', 'music']",
#        "['action', 'family', 'fantasy', 'animation']",
#        "['comedy', 'scifi', 'action', 'drama', 'family']",
#        "['comedy', 'family', 'fantasy', 'scifi', 'action']",
#        "['animation', 'fantasy', 'romance', 'comedy', 'family']",
#        "['animation', 'family', 'romance', 'thriller']",
#        "['documentation', 'action']",
#        "['animation', 'fantasy', 'family']", "['music', 'family']",
#        "['drama', 'comedy', 'family', 'fantasy']",
#        "['drama', 'comedy', 'family', 'music']",
#        "['comedy', 'crime', 'drama', 'family', 'scifi']",
#        "['animation', 'action', 'family', 'scifi']",
#        "['action', 'family', 'fantasy']", "['drama', 'romance']",
#        "['music', 'drama', 'family']",
#        "['comedy', 'family', 'scifi', 'animation', 'action']",
#        "['animation', 'action', 'fantasy', 'scifi']",
#        "['drama', 'scifi', 'action', 'thriller']",
#        "['action', 'scifi', 'comedy']",
#        "['action', 'scifi', 'fantasy', 'drama', 'animation', 'family']",
#        "['comedy', 'history', 'documentation']",
#        "['action', 'reality', 'comedy']",
#        "['action', 'comedy', 'fantasy', 'family']",
#        "['scifi', 'action', 'thriller']",
#        "['fantasy', 'animation', 'family', 'comedy']",
#        "['fantasy', 'family', 'thriller']",
#        "['comedy', 'family', 'fantasy', 'horror', 'animation']",
#        "['comedy', 'action', 'family', 'scifi', 'drama', 'animation']",
#        "['documentation', 'reality']",
#        "['documentation', 'comedy', 'reality']",
#        "['scifi', 'drama', 'romance', 'fantasy']",
#        "['comedy', 'family', 'drama', 'fantasy', 'european']",
#        "['drama', 'documentation', 'sport', 'family', 'history']",
#        "['action', 'scifi', 'comedy', 'drama', 'family', 'animation']",
#        "['animation', 'horror', 'comedy', 'family', 'fantasy']",
#        "['documentation', 'sport']",
#        "['comedy', 'family', 'music', 'drama']",
#        "['documentation', 'reality', 'european']",
#        "['comedy', 'family', 'sport', 'animation']",
#        "['thriller', 'action', 'fantasy']",
#        "['family', 'action', 'animation', 'fantasy']",
#        "['animation', 'scifi', 'family', 'action']",
#        "['comedy', 'documentation', 'family', 'sport', 'fantasy', 'animation', 'drama']",
#        "['scifi', 'animation', 'comedy', 'family', 'fantasy']",
#        "['comedy', 'crime', 'history', 'drama', 'family']",
#        "['western', 'action', 'comedy', 'family', 'animation']",
#        "['action', 'animation', 'comedy', 'family']",
#        "['comedy', 'drama', 'horror']",
#        "['animation', 'action', 'family', 'comedy', 'drama']",
#        "['drama', 'family', 'action', 'comedy', 'fantasy', 'romance', 'animation']",
#        "['action', 'drama', 'family', 'sport']",
#        "['documentation', 'drama']",
#        "['animation', 'fantasy', 'music', 'family']", "['fantasy']",
#        "['scifi', 'animation', 'family']", "['drama', 'history']",
#        "['crime', 'action', 'scifi', 'thriller', 'drama', 'fantasy']",
#        "['action', 'comedy', 'scifi']", "['scifi', 'action', 'drama']",
#        "['action', 'family', 'fantasy', 'romance', 'animation']",
#        "['drama', 'scifi', 'action', 'crime', 'thriller']",
#        "['drama', 'family', 'fantasy', 'thriller', 'european']",
#        "['scifi', 'crime', 'action', 'comedy']",
#        "['drama', 'comedy', 'family', 'fantasy', 'scifi', 'animation']",
#        "['drama', 'scifi', 'action', 'crime']",
#        "['scifi', 'action', 'thriller', 'crime', 'drama']",
#        "['comedy', 'drama', 'action', 'family']",
#        "['reality', 'comedy', 'thriller']",
#        "['comedy', 'crime', 'animation', 'action', 'family']",
#        "['family', 'comedy', 'animation', 'drama']",
#        "['scifi', 'action', 'fantasy', 'thriller']",
#        "['comedy', 'drama', 'music', 'family', 'european']",
#        "['action', 'scifi', 'drama', 'fantasy', 'thriller', 'animation', 'comedy', 'family']",
#        "['fantasy', 'scifi', 'animation', 'action', 'comedy', 'family', 'european']",
#        "['music', 'animation', 'family', 'fantasy']",
#        "['family', 'music', 'action', 'comedy', 'fantasy']",
#        "['family', 'action', 'animation', 'comedy', 'drama']",
#        "['action', 'comedy', 'drama', 'family', 'scifi', 'animation']",
#        "['drama', 'fantasy', 'animation', 'comedy', 'family', 'action']",
#        "['history', 'thriller', 'action', 'drama']",
#        "['family', 'music', 'animation', 'action', 'drama', 'comedy', 'fantasy']",
#        "['animation', 'family', 'comedy', 'scifi', 'action', 'drama', 'fantasy', 'romance']",
#        "['animation', 'action', 'comedy', 'drama', 'family', 'fantasy']",
#        "['documentation', 'reality', 'action']",
#        "['animation', 'comedy', 'family', 'fantasy', 'action']",
#        "['fantasy', 'european']", "['documentation', 'sport', 'history']",
#        "['animation', 'drama', 'family', 'fantasy', 'comedy']",
#        "['music']", "['scifi', 'action', 'comedy', 'family']",
#        "['animation', 'fantasy', 'family', 'romance', 'comedy']",
#        "['fantasy', 'family', 'action', 'comedy', 'drama']",
#        "['animation', 'comedy', 'scifi', 'action']",
#        "['family', 'animation', 'action', 'scifi']",
#        "['comedy', 'family', 'documentation', 'romance']",
#        "['animation', 'family', 'fantasy', 'comedy', 'scifi', 'action', 'drama']",
#        "['scifi', 'comedy', 'drama', 'family']",
#        "['family', 'action', 'animation', 'comedy', 'fantasy', 'music']",
#        "['music', 'documentation', 'comedy', 'family']",
#        "['drama', 'thriller', 'family', 'reality']",
#        "['scifi', 'animation', 'comedy', 'family', 'fantasy', 'romance']",
#        "['action', 'comedy', 'family']",
#        "['comedy', 'fantasy', 'drama', 'family']",
#        "['romance', 'comedy', 'drama', 'family', 'music']",
#        "['family', 'comedy', 'animation']", "['drama', 'music']",
#        "['horror', 'thriller']", "['family', 'comedy', 'reality']",
#        "['family', 'reality']",
#        "['animation', 'comedy', 'action', 'family', 'fantasy']",
#        "['action', 'crime', 'drama', 'thriller', 'scifi']",
#        "['drama', 'action', 'scifi', 'thriller']",
#        "['scifi', 'action', 'fantasy', 'comedy']",
#        "['animation', 'fantasy', 'comedy', 'family', 'music', 'drama', 'european']",
#        "['action', 'scifi', 'crime', 'fantasy']",
#        "['scifi', 'action', 'animation', 'comedy', 'crime', 'fantasy']",
#        "['scifi', 'action', 'comedy']",
#        "['action', 'comedy', 'animation', 'drama', 'scifi', 'fantasy', 'european']",
#        "['action', 'documentation', 'sport']",
#        "['action', 'animation', 'family', 'scifi', 'comedy']",
#        "['animation', 'family', 'fantasy', 'comedy', 'scifi', 'action']",
#        "['scifi', 'action', 'crime', 'drama', 'documentation']",
#        "['action', 'comedy', 'family', 'fantasy', 'drama', 'animation']",
#        "['documentation', 'family', 'music']",
#        "['romance', 'action', 'family', 'fantasy']",
#        "['documentation', 'crime', 'history']",
#        "['animation', 'family', 'action', 'comedy', 'drama', 'fantasy']",
#        "['animation', 'drama', 'scifi', 'comedy', 'family', 'fantasy']",
#        "['scifi', 'animation', 'action', 'family']",
#        "['animation', 'comedy', 'family', 'sport', 'drama', 'fantasy']",
#        "['comedy', 'family', 'action', 'animation', 'scifi']",
#        "['action', 'animation', 'comedy', 'drama', 'family', 'fantasy', 'scifi']",
#        "['animation', 'comedy', 'drama', 'family']",
#        "['documentation', 'action', 'drama', 'fantasy', 'scifi']",
#        "['documentation', 'history', 'sport', 'action', 'scifi']",
#        "['documentation', 'thriller', 'drama', 'action', 'history', 'comedy', 'scifi', 'horror', 'romance']",
#        "['scifi', 'documentation', 'drama']",
#        "['comedy', 'sport', 'family']", "['history', 'documentation']",
#        "['fantasy', 'animation', 'comedy', 'family']",
#        "['comedy', 'animation', 'family', 'thriller']",
#        "['family', 'scifi', 'animation', 'action', 'drama']",
#        "['comedy', 'family', 'fantasy', 'romance']",
#        "['fantasy', 'comedy']",
#        "['scifi', 'animation', 'action', 'fantasy', 'comedy']",
#        "['animation', 'action', 'comedy', 'drama', 'family']",
#        "['action', 'thriller', 'documentation']",
#        "['animation', 'horror']",
#        "['scifi', 'comedy', 'family', 'animation']",
#        "['action', 'family', 'fantasy', 'animation', 'comedy']",
#        "['music', 'documentation', 'reality']",
#        "['animation', 'scifi', 'comedy', 'family', 'fantasy']",
#        "['documentation', 'drama', 'family', 'action', 'comedy']",
#        "['drama', 'documentation']",
#        "['scifi', 'action', 'drama', 'fantasy']",
#        "['action', 'comedy', 'animation', 'family', 'fantasy', 'thriller', 'horror', 'drama', 'scifi']",
#        "['romance', 'comedy', 'drama', 'sport']",
#        "['fantasy', 'comedy', 'drama', 'family', 'music', 'scifi', 'animation']",
#        "['action', 'scifi', 'horror']",
#        "['comedy', 'drama', 'family', 'thriller', 'fantasy', 'animation', 'scifi', 'music', 'action', 'crime']",
#        "['scifi', 'comedy', 'action', 'drama', 'thriller', 'family', 'fantasy', 'animation']",
#        "['drama', 'music', 'history']",
#        "['comedy', 'animation', 'family', 'fantasy', 'drama']",
#        "['drama', 'comedy', 'animation', 'family']",
#        "['action', 'fantasy', 'comedy', 'family']",
#        "['music', 'drama', 'fantasy']",
#        "['drama', 'animation', 'western', 'family']",
#        "['scifi', 'action', 'animation', 'family', 'comedy']",
#        "['action', 'scifi', 'drama', 'fantasy', 'european']",
#        "['documentation', 'comedy']",
#        "['fantasy', 'drama', 'action', 'family']",
#        "['action', 'family', 'fantasy', 'scifi']",
#        "['family', 'action', 'european', 'drama', 'history']",
#        "['fantasy', 'action', 'family']",
#        "['comedy', 'drama', 'family', 'fantasy', 'animation']",
#        "['action', 'fantasy', 'romance', 'family', 'comedy', 'drama']",
#        "['documentation', 'war']",
#        "['fantasy', 'thriller', 'action', 'drama', 'family', 'reality']",
#        "['animation', 'family', 'fantasy', 'western', 'comedy', 'scifi']",
#        "['romance', 'comedy', 'family', 'fantasy', 'music']",
#        "['comedy', 'documentation', 'family', 'fantasy', 'animation']",
#        "['drama', 'fantasy', 'romance', 'comedy', 'family']",
#        "['fantasy', 'comedy', 'drama', 'family']",
#        "['animation', 'fantasy', 'family', 'comedy', 'drama']",
#        "['documentation', 'history', 'crime', 'european']",
#        "['comedy', 'action']",
#        "['fantasy', 'family', 'thriller', 'comedy', 'drama']",
#        "['romance', 'comedy', 'family', 'animation', 'drama']",
#        "['documentation', 'music', 'drama']",
#        "['reality', 'scifi', 'documentation']",
#        "['drama', 'family', 'music', 'romance', 'action', 'comedy']",
#        "['animation', 'fantasy', 'action']",
#        "['comedy', 'family', 'animation', 'scifi', 'action', 'thriller', 'fantasy']",
#        "['action', 'animation', 'scifi', 'family']",
#        "['scifi', 'family', 'comedy']",
#        "['music', 'animation', 'comedy', 'family']",
#        "['animation', 'scifi', 'action']",
#        "['action', 'comedy', 'thriller', 'family', 'scifi']",
#        "['animation', 'action', 'comedy', 'family', 'scifi']",
#        "['animation', 'comedy', 'drama', 'fantasy', 'family', 'romance', 'horror']",
#        "['romance', 'animation', 'comedy', 'family', 'fantasy', 'music']",
#        "['action', 'scifi', 'animation', 'family']",
#        "['documentation', 'music', 'comedy', 'drama']",
#        "['scifi', 'animation', 'action']", "['drama', 'crime']",
#        "['scifi', 'animation', 'romance', 'family']",
#        "['thriller', 'documentation']", "['music', 'comedy', 'family']",
#        "['documentation', 'music', 'drama', 'comedy']",
#        "['action', 'reality', 'documentation']",
#        "['scifi', 'animation', 'action', 'drama', 'fantasy']",
#        "['action', 'scifi', 'drama', 'fantasy', 'thriller']",
#        "['drama', 'scifi', 'action', 'war', 'thriller']",
#        "['action', 'thriller']",
#        "['action', 'drama', 'scifi', 'fantasy', 'romance']",
#        "['scifi', 'action', 'drama', 'fantasy', 'horror', 'thriller']",
#        "['drama', 'scifi', 'fantasy', 'action']",
#        "['action', 'scifi', 'fantasy', 'romance', 'western', 'family']",
#        "['scifi', 'comedy', 'drama', 'action']",
#        "['scifi', 'drama', 'fantasy', 'romance', 'action', 'comedy']",
#        "['action', 'documentation']",
#        "['comedy', 'scifi', 'action', 'fantasy']",
#        "['comedy', 'action', 'fantasy', 'romance', 'scifi', 'music']",
#        "['action', 'comedy', 'scifi', 'drama', 'fantasy', 'crime', 'family']",
#        "['drama', 'comedy', 'action', 'crime', 'scifi']",
#        "['fantasy', 'action', 'horror', 'scifi']",
#        "['action', 'drama', 'scifi']",
#        "['action', 'scifi', 'fantasy', 'animation']",
#        "['scifi', 'action', 'comedy', 'family', 'fantasy', 'animation']",
#        "['drama', 'family', 'fantasy', 'romance', 'animation', 'comedy', 'action']",
#        "['horror', 'action', 'fantasy', 'thriller', 'comedy', 'drama']",
#        "['comedy', 'action', 'fantasy', 'scifi']",
#        "['comedy', 'drama', 'family', 'fantasy', 'romance']",
#        "['family', 'fantasy', 'comedy', 'romance', 'animation']",
#        "['family', 'comedy', 'drama', 'sport']",
#        "['family', 'fantasy', 'comedy', 'horror', 'romance']",
#        "['thriller', 'drama', 'documentation', 'action']",
#        "['scifi', 'horror']",
#        "['comedy', 'family', 'fantasy', 'horror', 'thriller', 'action', 'animation']",
#        "['family', 'sport', 'animation', 'comedy']",
#        "['action', 'animation', 'comedy', 'drama', 'family', 'scifi', 'fantasy']",
#        "['sport', 'comedy', 'drama']",
#        "['fantasy', 'scifi', 'comedy', 'action']",
#        "['romance', 'crime', 'drama']",
#        "['scifi', 'action', 'fantasy', 'drama']",
#        "['documentation', 'history', 'war']",
#        "['comedy', 'family', 'fantasy', 'drama', 'animation']",
#        "['reality', 'scifi', 'action', 'fantasy']",
#        "['scifi', 'documentation']",
#        "['animation', 'action', 'comedy', 'family', 'scifi', 'fantasy']",
#        "['comedy', 'drama', 'family', 'horror']",
#        "['scifi', 'family', 'romance']", "['comedy', 'crime', 'drama']",
#        "['fantasy', 'scifi', 'animation']",
#        "['animation', 'fantasy', 'scifi', 'comedy', 'crime', 'action', 'family']",
#        "['animation', 'scifi', 'family', 'comedy']",
#        "['comedy', 'crime', 'family', 'action', 'drama']",
#        "['documentation', 'music', 'history']", "['scifi', 'animation']",
#        "['comedy', 'crime', 'drama', 'family', 'action']",
#        "['action', 'animation', 'comedy', 'drama', 'family', 'fantasy']",
#        "['comedy', 'drama', 'sport']",
#        "['family', 'comedy', 'music', 'drama']",
#        "['romance', 'animation', 'family', 'fantasy', 'music']",
#        "['fantasy', 'drama']",
#        "['war', 'drama', 'romance', 'thriller', 'crime']",
#        "['scifi', 'comedy', 'drama', 'fantasy']",
#        "['action', 'family', 'animation', 'comedy', 'fantasy', 'drama']",
#        "['reality', 'documentation', 'sport']",
#        "['fantasy', 'scifi', 'animation', 'action', 'comedy', 'family']",
#        "['reality', 'family']", "['family', 'comedy', 'fantasy']",
#        "['scifi', 'animation', 'family', 'comedy']",
#        "['animation', 'comedy', 'family', 'fantasy', 'drama']",
#        "['comedy', 'romance', 'music', 'drama', 'family']",
#        "['family', 'fantasy', 'scifi', 'animation', 'action', 'comedy']",
#        "['fantasy', 'family', 'comedy', 'romance']",
#        "['comedy', 'animation', 'action', 'family', 'fantasy', 'scifi']",
#        "['documentation', 'music', 'family', 'reality']",
#        "['family', 'animation', 'comedy', 'scifi']",
#        "['animation', 'scifi', 'action', 'horror', 'comedy', 'fantasy', 'family']",
#        "['comedy', 'family', 'animation', 'music', 'thriller', 'fantasy', 'horror', 'scifi']",
#        "['comedy', 'family', 'fantasy', 'romance', 'animation', 'action']",
#        "['family', 'animation']", "['drama', 'animation']",
#        "['music', 'documentation', 'fantasy']", "['drama', 'reality']",
#        "['comedy', 'family', 'animation', 'drama']",
#        "['animation', 'action', 'comedy', 'family', 'western']",
#        "['animation', 'comedy', 'action']",
#        "['drama', 'music', 'romance']", "['documentation', 'animation']",
#        "['family', 'fantasy', 'animation', 'action', 'comedy']",
#        "['romance', 'animation', 'comedy', 'music']",
#        "['scifi', 'animation', 'action', 'comedy', 'family', 'fantasy']",
#        "['scifi', 'action', 'comedy', 'drama']",
#        "['sport', 'romance', 'drama', 'family', 'comedy']",
#        "['comedy', 'family', 'history', 'music']",
#        "['family', 'animation', 'action', 'scifi', 'comedy', 'fantasy']",
#        "['reality', 'documentation', 'action']"], dtype=object)

# %% [markdown]
# The values for genres are grouped as arrays for each row, which will prove complicated to work with if left in that state.

# %% [markdown]
# Removing some columns that hold no impact for the project:

# %%
drop_df = full_df.drop(['id', 'imdb_id', 'person_id', 'character', 'role'], axis=1)
drop_df.head()
# Out:
#                     title   type  \
# 0  Miracle on 34th Street  MOVIE
# 1  Miracle on 34th Street  MOVIE
# 2  Miracle on 34th Street  MOVIE
# 3  Miracle on 34th Street  MOVIE
# 4  Miracle on 34th Street  MOVIE
#
#                                          description  release_year  \
# 0  Kris Kringle, seemingly the embodiment of Sant...          1947
# 1  Kris Kringle, seemingly the embodiment of Sant...          1947
# 2  Kris Kringle, seemingly the embodiment of Sant...          1947
# 3  Kris Kringle, seemingly the embodiment of Sant...          1947
# 4  Kris Kringle, seemingly the embodiment of Sant...          1947
#
#   age_certification  runtime                         genres  \
# 0                 G       96  ['family', 'comedy', 'drama']
# 1                 G       96  ['family', 'comedy', 'drama']
# 2                 G       96  ['family', 'comedy', 'drama']
# 3                 G       96  ['family', 'comedy', 'drama']
# 4                 G       96  ['family', 'comedy', 'drama']
#
#   production_countries  seasons  imdb_score  imdb_votes  tmdb_popularity  \
# 0               ['US']      NaN         7.9     50969.0           23.515
# 1               ['US']      NaN         7.9     50969.0           23.515
# 2               ['US']      NaN         7.9     50969.0           23.515
# 3               ['US']      NaN         7.9     50969.0           23.515
# 4               ['US']      NaN         7.9     50969.0           23.515
#
#    tmdb_score            name
# 0       7.388  Maureen O'Hara
# 1       7.388      John Payne
# 2       7.388    Edmund Gwenn
# 3       7.388    Natalie Wood
# 4       7.388     Porter Hall

# %% [markdown]
# The column of actors could still be groupped and age certifications should be inspected along with seasons. All the missing values for scores should be replaced with average.

# %%
drop_df.age_certification.unique()
# Out:
# array(['G', nan, 'PG', 'TV-G', 'TV-PG', 'TV-MA', 'PG-13', 'TV-Y7',
#        'TV-Y7-FV', 'TV-Y', 'TV-14', 'R'], dtype=object)

# %% [markdown]
# Age_certification appears to contain several rating scales which can be homogenized, also due to the importance of maintaining a proper hierarchy on the ratings all the rows with nan values will be dropped. For the new rating format:<br>
# 'G', 'TV-G', 'TV-Y' = '0' <br>
# 'PG', 'TV-PG', 'TV-Y7', 'TV-Y7-FV' = '1'<br>
# 'PG-13', 'TV-14' = '2'<br>
# 'TV-MA', 'R' = '3'<br>

# %%
agefix_df = drop_df.dropna(subset = ['age_certification'])
agechange_df = agefix_df.replace({'age_certification' : {'G' : 0, 'TV-G' : 0,'TV-Y' : 0, 'PG' : 1, 'TV-PG' : 1,
                                                         'TV-Y7' : 1, 'TV-Y7-FV' : 1, 'PG-13' : 2, 'TV-14' : 2,
                                                        'TV-MA' : 3, 'R' : 3}})
agechange_df.age_certification.unique()
# Out:
# array([0, 1, 3, 2], dtype=int64)

# %% [markdown]
# Now replace the missing values in the rating columns with their respective average. (imdb_score,imdb_votes,tmdb_popularity, tmdb_score)

# %%
mean_imsc = agechange_df['imdb_score'].mean()
mean_imvo = agechange_df['imdb_votes'].mean()
mean_tmpo = agechange_df['tmdb_popularity'].mean()
mean_tmsc = agechange_df['tmdb_score'].mean()
mean_df = agechange_df.fillna({'imdb_score': mean_imsc, 
                               'imdb_votes': mean_imvo, 
                               'tmdb_popularity': mean_tmpo, 
                               'tmdb_score': mean_tmsc})
mean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 27498 entries, 0 to 30688
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 27498 non-null  object
#  1   type                  27498 non-null  object
#  2   description           27498 non-null  object
#  3   release_year          27498 non-null  int64
#  4   age_certification     27498 non-null  int64
#  5   runtime               27498 non-null  int64
#  6   genres                27498 non-null  object
#  7   production_countries  27498 non-null  object
#  8   seasons               2061 non-null   float64
#  9   imdb_score            27498 non-null  float64
#  10  imdb_votes            27498 non-null  float64
#  11  tmdb_popularity       27498 non-null  float64
#  12  tmdb_score            27498 non-null  float64
#  13  name                  27498 non-null  object
# dtypes: float64(5), int64(3), object(6)
# memory usage: 3.1+ MB

# %% [markdown]
# Something could be done with the 'seasons' column, should check if every show has seasons values first.

# %%
mean_df.type.unique()
# Out:
# array(['MOVIE', 'SHOW'], dtype=object)

# %%
def show_check(mean_df):
    idtype = mean_df.index[mean_df['type']== 'SHOW']
    if mean_df.loc[idtype, 'seasons'].isna().any():
        return True
    else:
        return False
    
show_check(mean_df)
# Out:
# False

# %% [markdown]
# All shows have valid 'seasons' values so only the movie types need to be filled.

# %%
mean_df = mean_df.fillna({'seasons':0})

# %%
lean_df = mean_df.groupby(['title','type','description','release_year','age_certification','runtime','genres','production_countries',
                          'imdb_score','imdb_votes','tmdb_popularity','tmdb_score'])['name'].apply(lambda x: list(x)).reset_index()
lean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1327 entries, 0 to 1326
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   title                 1327 non-null   object
#  1   type                  1327 non-null   object
#  2   description           1327 non-null   object
#  3   release_year          1327 non-null   int64
#  4   age_certification     1327 non-null   int64
#  5   runtime               1327 non-null   int64
#  6   genres                1327 non-null   object
#  7   production_countries  1327 non-null   object
#  8   imdb_score            1327 non-null   float64
#  9   imdb_votes            1327 non-null   float64
#  10  tmdb_popularity       1327 non-null   float64
#  11  tmdb_score            1327 non-null   float64
#  12  name                  1327 non-null   object
# dtypes: float64(4), int64(3), object(6)
# memory usage: 134.9+ KB

# %%
   lean_df.head(10)
# Out:
#                                          title   type  \
# 0                              'Twas the Night  MOVIE
# 1                   10 Things I Hate About You  MOVIE
# 2                         101 Dalmatian Street   SHOW
# 3                               101 Dalmatians  MOVIE
# 4  101 Dalmatians II: Patch's London Adventure  MOVIE
# 5                   101 Dalmatians: The Series   SHOW
# 6                               102 Dalmatians  MOVIE
# 7                 20,000 Leagues Under the Sea  MOVIE
# 8                                 22 vs. Earth  MOVIE
# 9                             3 Men and a Baby  MOVIE
#
#                                          description  release_year  \
# 0  A mischievous 14-year-old boy and his irrespon...          2001
# 1  On the first day at his new school, Cameron in...          1999
# 2  Follow the adventures of eldest siblings Dolly...          2019
# 3  An evil, high-fashion designer plots to steal ...          1996
# 4  Being one of 101 takes its toll on Patch, who ...          2002
# 5  After foiling Cruella DeVil's plot to make a f...          1997
# 6  Get ready for a howling good time as an all ne...          2000
# 7  A ship sent to investigate a wave of mysteriou...          1955
# 8  Set before the events of ‘Soul’, 22 refuses to...          2021
# 9  Three bachelors find themselves forced to take...          1987
#
#    age_certification  runtime  \
# 0                  0       84
# 1                  2       97
# 2                  1       17
# 3                  0      103
# 4                  0       74
# 5                  0       22
# 6                  0      100
# 7                  0      127
# 8                  0        9
# 9                  1      102
#
#                                               genres production_countries  \
# 0                               ['comedy', 'family']               ['US']
# 1                     ['drama', 'romance', 'comedy']               ['US']
# 2                  ['animation', 'family', 'comedy']               ['GB']
# 3                      ['comedy', 'family', 'crime']         ['US', 'GB']
# 4                                         ['comedy']               ['US']
# 5        ['action', 'comedy', 'family', 'animation']               ['US']
# 6                               ['family', 'comedy']               ['US']
# 7  ['action', 'drama', 'family', 'fantasy', 'scifi']               ['US']
# 8                           ['animation', 'fantasy']               ['US']
# 9                      ['comedy', 'drama', 'family']               ['US']
#
#    imdb_score     imdb_votes  tmdb_popularity  tmdb_score  \
# 0    5.200000    1126.000000            3.911       5.365
# 1    7.300000  351998.000000           32.094       7.560
# 2    6.000000     419.000000           17.398       7.500
# 3    5.700000  113287.000000           34.265       5.896
# 4    6.647706  217526.383949           32.759       6.002
# 5    6.100000    1708.000000           27.092       6.837
# 6    4.800000   38296.000000           15.584       5.476
# 7    7.200000   34959.000000           19.999       7.065
# 8    6.647706  217526.383949           29.662       7.100
# 9    6.100000   55164.000000           12.930       6.185
#
#                                                 name
# 0  [Bryan Cranston, Josh Zuckerman, Brenda Grate,...
# 1  [Julia Stiles, Heath Ledger, Joseph Gordon-Lev...
# 2  [Bert Davis, Margot Powell, Michaela Dietz, Jo...
# 3  [Glenn Close, Jeff Daniels, Joely Richardson, ...
# 4  [Barry Bostwick, Jason Alexander, Martin Short...
# 5  [Kath Soucie, Tara Strong, Jeff Bennett, Frank...
# 6  [Glenn Close, Ioan Gruffudd, Alice Evans, Tim ...
# 7  [Kirk Douglas, James Mason, Paul Lukas, Peter ...
# 8  [Tina Fey, Alice Braga, Richard Ayoade, Micah ...
# 9  [Tom Selleck, Steve Guttenberg, Ted Danson, Na...

# %% [markdown]
# ## 3. Data Cleaning
# ---

# %% [markdown]
# The differnt rating scores could be consolidated. After some research the imbd votes and tmdb popularity columns should be dropped since there is no clear description of how the values are obtained. For the sake of using the data from both platforms a new column showing the mean of both scores and using that instead. Doing so will probably have little impact since the values for both of them are very similar.

# %%
lean_df['combined_score'] = lean_df[['imdb_score','tmdb_score']].mean(axis=1).round(2)
clear_df = lean_df.drop(['imdb_score','imdb_votes','tmdb_popularity','tmdb_score'], axis=1)

clear_df.head()
# Out:
#                                          title   type  \
# 0                              'Twas the Night  MOVIE
# 1                   10 Things I Hate About You  MOVIE
# 2                         101 Dalmatian Street   SHOW
# 3                               101 Dalmatians  MOVIE
# 4  101 Dalmatians II: Patch's London Adventure  MOVIE
#
#                                          description  release_year  \
# 0  A mischievous 14-year-old boy and his irrespon...          2001
# 1  On the first day at his new school, Cameron in...          1999
# 2  Follow the adventures of eldest siblings Dolly...          2019
# 3  An evil, high-fashion designer plots to steal ...          1996
# 4  Being one of 101 takes its toll on Patch, who ...          2002
#
#    age_certification  runtime                             genres  \
# 0                  0       84               ['comedy', 'family']
# 1                  2       97     ['drama', 'romance', 'comedy']
# 2                  1       17  ['animation', 'family', 'comedy']
# 3                  0      103      ['comedy', 'family', 'crime']
# 4                  0       74                         ['comedy']
#
#   production_countries                                               name  \
# 0               ['US']  [Bryan Cranston, Josh Zuckerman, Brenda Grate,...
# 1               ['US']  [Julia Stiles, Heath Ledger, Joseph Gordon-Lev...
# 2               ['GB']  [Bert Davis, Margot Powell, Michaela Dietz, Jo...
# 3         ['US', 'GB']  [Glenn Close, Jeff Daniels, Joely Richardson, ...
# 4               ['US']  [Barry Bostwick, Jason Alexander, Martin Short...
#
#    combined_score
# 0            5.28
# 1            7.43
# 2            6.75
# 3            5.80
# 4            6.32

# %% [markdown]
# Hot and label encoding can be applied to some columns, also genres and prod countries need to be turned to actual lists. Further manipulation can be used to turn the actor names into actual lists.

# %%
type(clear_df['name'].iloc[0])
# Out:
# list

# %%
#not used, found better fix using lambda 
#Mod to the ast lit eval for it to get through all the extra things cause normal is not running
def custom_literal_eval(s):
    
    s = re.sub(r"'([^']*)'", r'\1', s)
    s = re.sub(r'\[|\]|\s', '', s)
    
    return ast.literal_eval(s)

# %%
#lean_df['genres'] = lean_df['genres'].apply(custom_literal_eval)
#lean_df['production_countries'] = lean_df['production_countries'].apply(custom_literal_eval)
clear_df['genres'] = clear_df['genres'].apply(lambda x: ast.literal_eval(x))


clear_df.head()
# Out:
#                                          title   type  \
# 0                              'Twas the Night  MOVIE
# 1                   10 Things I Hate About You  MOVIE
# 2                         101 Dalmatian Street   SHOW
# 3                               101 Dalmatians  MOVIE
# 4  101 Dalmatians II: Patch's London Adventure  MOVIE
#
#                                          description  release_year  \
# 0  A mischievous 14-year-old boy and his irrespon...          2001
# 1  On the first day at his new school, Cameron in...          1999
# 2  Follow the adventures of eldest siblings Dolly...          2019
# 3  An evil, high-fashion designer plots to steal ...          1996
# 4  Being one of 101 takes its toll on Patch, who ...          2002
#
#    age_certification  runtime                       genres  \
# 0                  0       84             [comedy, family]
# 1                  2       97     [drama, romance, comedy]
# 2                  1       17  [animation, family, comedy]
# 3                  0      103      [comedy, family, crime]
# 4                  0       74                     [comedy]
#
#   production_countries                                               name  \
# 0               ['US']  [Bryan Cranston, Josh Zuckerman, Brenda Grate,...
# 1               ['US']  [Julia Stiles, Heath Ledger, Joseph Gordon-Lev...
# 2               ['GB']  [Bert Davis, Margot Powell, Michaela Dietz, Jo...
# 3         ['US', 'GB']  [Glenn Close, Jeff Daniels, Joely Richardson, ...
# 4               ['US']  [Barry Bostwick, Jason Alexander, Martin Short...
#
#    combined_score
# 0            5.28
# 1            7.43
# 2            6.75
# 3            5.80
# 4            6.32

# %%
clear_df['production_countries'] = clear_df['production_countries'].apply(lambda x: ast.literal_eval(x))
type(clear_df['production_countries'].iloc[0])
# Out:
# list

# %%
clear_df.rename(columns = {'name':'actors'}, inplace = True)
clear_df.head()
# Out:
#                                          title   type  \
# 0                              'Twas the Night  MOVIE
# 1                   10 Things I Hate About You  MOVIE
# 2                         101 Dalmatian Street   SHOW
# 3                               101 Dalmatians  MOVIE
# 4  101 Dalmatians II: Patch's London Adventure  MOVIE
#
#                                          description  release_year  \
# 0  A mischievous 14-year-old boy and his irrespon...          2001
# 1  On the first day at his new school, Cameron in...          1999
# 2  Follow the adventures of eldest siblings Dolly...          2019
# 3  An evil, high-fashion designer plots to steal ...          1996
# 4  Being one of 101 takes its toll on Patch, who ...          2002
#
#    age_certification  runtime                       genres  \
# 0                  0       84             [comedy, family]
# 1                  2       97     [drama, romance, comedy]
# 2                  1       17  [animation, family, comedy]
# 3                  0      103      [comedy, family, crime]
# 4                  0       74                     [comedy]
#
#   production_countries                                             actors  \
# 0                 [US]  [Bryan Cranston, Josh Zuckerman, Brenda Grate,...
# 1                 [US]  [Julia Stiles, Heath Ledger, Joseph Gordon-Lev...
# 2                 [GB]  [Bert Davis, Margot Powell, Michaela Dietz, Jo...
# 3             [US, GB]  [Glenn Close, Jeff Daniels, Joely Richardson, ...
# 4                 [US]  [Barry Bostwick, Jason Alexander, Martin Short...
#
#    combined_score
# 0            5.28
# 1            7.43
# 2            6.75
# 3            5.80
# 4            6.32

# %% [markdown]
# ## After previous fails in working with hot encoding a different approach will be tried.

# %% [markdown]
# Text needs to be properly processed in this version. Title as index, everything else as bag of words.

# %% [markdown]
# ### Experimental transformation
# ---

# %% [markdown]
# Checking for how many unique values there are in the columns that have to be encoded.

# %%
unique_genres = set()
for genre_list in clear_df['genres']:
    unique_genres.update(genre_list)
num_unique_genres = len(unique_genres)
print("Number of unique genres:", num_unique_genres)

unique_actors = set()
for actor_list in clear_df['actors']:
    unique_actors.update(actor_list)
num_unique_actors = len(unique_actors)
print("Number of unique actors:", num_unique_actors)

unique_countries = set()
for country_list in clear_df['production_countries']:
    unique_countries.update(country_list)
num_unique_countries = len(unique_countries)
print("Number of unique countries:", num_unique_countries)
# Out:
# Number of unique genres: 19
# Number of unique actors: 18155
# Number of unique countries: 36

# %% [markdown]
# The number of actors is very high, might prove useful to use multilabelbinarizer. This was the main issue with the past approach, bag of words will be used instead.

# %% [markdown]
# Now text processing should be considered. Lowercasing, stopwords (NLTK or SpaCy), tokenization. PCA afterwards.

# %%
pra_df = clear_df

# %%
pra_df['description'] = clear_df['description'].str.lower()

nltk.download('stopwords')
from nltk.corpus import stopwords

trimwords = set(stopwords.words('english'))

pra_df['description'] = clear_df['description'].apply(lambda x: ' '.join(word for word in x.
                                                                             split() if word not in trimwords))
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\logan\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
clear_df['description'] = clear_df['description'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in x.
                                                                              split()]))
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\logan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
nltk.download('punkt')
from nltk.tokenize import word_tokenize
def tokenize_text(text):
    tokens = word_tokenize(text)
    return tokens

pra_df['description'] = clear_df['description'].apply(lambda x: tokenize_text(x))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\logan\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# For the model selection, given the objective of the project and the features available, choosing supervised learning would be optimal and using nearest neightbor might be the best suited.

# %%
pre_df = pra_df.set_index('title')
pre_df.head()
# Out:
#                                               type  \
# title
# 'Twas the Night                              MOVIE
# 10 Things I Hate About You                   MOVIE
# 101 Dalmatian Street                          SHOW
# 101 Dalmatians                               MOVIE
# 101 Dalmatians II: Patch's London Adventure  MOVIE
#
#                                                                                    description  \
# title
# 'Twas the Night                              [mischievous, 14-year-old, boy, irresponsible,...
# 10 Things I Hate About You                   [first, day, new, school, ,, cameron, instantl...
# 101 Dalmatian Street                         [follow, adventure, eldest, sibling, dolly, dy...
# 101 Dalmatians                               [evil, ,, high-fashion, designer, plot, steal,...
# 101 Dalmatians II: Patch's London Adventure  [one, 101, take, toll, patch, ,, feel, unique,...
#
#                                              release_year  age_certification  \
# title
# 'Twas the Night                                      2001                  0
# 10 Things I Hate About You                           1999                  2
# 101 Dalmatian Street                                 2019                  1
# 101 Dalmatians                                       1996                  0
# 101 Dalmatians II: Patch's London Adventure          2002                  0
#
#                                              runtime  \
# title
# 'Twas the Night                                   84
# 10 Things I Hate About You                        97
# 101 Dalmatian Street                              17
# 101 Dalmatians                                   103
# 101 Dalmatians II: Patch's London Adventure       74
#
#                                                                   genres  \
# title
# 'Twas the Night                                         [comedy, family]
# 10 Things I Hate About You                      [drama, romance, comedy]
# 101 Dalmatian Street                         [animation, family, comedy]
# 101 Dalmatians                                   [comedy, family, crime]
# 101 Dalmatians II: Patch's London Adventure                     [comedy]
#
#                                             production_countries  \
# title
# 'Twas the Night                                             [US]
# 10 Things I Hate About You                                  [US]
# 101 Dalmatian Street                                        [GB]
# 101 Dalmatians                                          [US, GB]
# 101 Dalmatians II: Patch's London Adventure                 [US]
#
#                                                                                         actors  \
# title
# 'Twas the Night                              [Bryan Cranston, Josh Zuckerman, Brenda Grate,...
# 10 Things I Hate About You                   [Julia Stiles, Heath Ledger, Joseph Gordon-Lev...
# 101 Dalmatian Street                         [Bert Davis, Margot Powell, Michaela Dietz, Jo...
# 101 Dalmatians                               [Glenn Close, Jeff Daniels, Joely Richardson, ...
# 101 Dalmatians II: Patch's London Adventure  [Barry Bostwick, Jason Alexander, Martin Short...
#
#                                              combined_score
# title
# 'Twas the Night                                        5.28
# 10 Things I Hate About You                             7.43
# 101 Dalmatian Street                                   6.75
# 101 Dalmatians                                         5.80
# 101 Dalmatians II: Patch's London Adventure            6.32

# %% [markdown]
# ## 4. Model Selection
# ---
# The recommendation system will be built using several techniques, including cosine similarity, Euclidean distance, and Jaccard similarity. The system will use these techniques to calculate similarity scores between movies or TV shows based on their features. The system will then provide a list of similar movies or TV shows based on the input of a user.

# %% [markdown]
# After further research on what could be the best way to use the dataset, hot encoding the actors appears to be a bad approach for its intended use. In the end, it seems that keeping the actors as a bag of words and finding cosine similarity  would be better.

# %% [markdown]
# This run will use TfidfVectorizer (creates a matrix for contained text). For simplicity all text from rows will be added in a single bag of words. In this case, the text columns need to be turned from lists to strings.

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

pre_df['type'] = pre_df['type'].apply(lambda x: ' '.join(x))
pre_df['description'] = pre_df['description'].apply(lambda x: ' '.join(x))
pre_df['genres'] = pre_df['genres'].apply(lambda x: ' '.join(x))
pre_df['production_countries'] = pre_df['production_countries'].apply(lambda x: ' '.join(x))
pre_df['actors'] = pre_df['actors'].apply(lambda x: ' '.join(x))

pre_df['text'] = pre_df['type'] + ' ' + pre_df['description'] + ' ' + pre_df['genres'] + ' ' + pre_df['production_countries'] + ' ' + pre_df['actors']

tfidf = TfidfVectorizer()
text_features = tfidf.fit_transform(pre_df['text'])

# %% [markdown]
# For the numerical data, standard scaler. The release year could be switched to years passed since release to have a better scale.

# %%
from sklearn.preprocessing import StandardScaler

num_features = StandardScaler().fit_transform(pre_df[['release_year','age_certification','runtime', 'combined_score']])

# %% [markdown]
# So now both text and num dataframes can be joint and then get the cosine similarity in a matrix.

# %%
features = np.concatenate([text_features.toarray(), num_features], axis=1)

# %%
from sklearn.metrics.pairwise import cosine_similarity

similarity_matrix = cosine_similarity(features)

# %% [markdown]
# Now for the query we can use the index which is the same as the movie titles and return similar items.

# %% [markdown]
# ## 5. Model Testing
# ---
# To evaluate the performance of the recommendation system, we will use metrics such as precision, recall, and F1-score. These metrics will help us determine how well the recommendation system is able to provide accurate recommendations to users.

# %%
titles = pre_df.index.tolist()

# %%
query_title = random.choice(titles)
print(query_title)
# Out:
# A Goofy Movie

# %%
query_index = pre_df.index.get_loc(query_title)
similarities = similarity_matrix[query_index]
most_similar_indices = similarities.argsort()[-6:-1]
most_similar_titles = pre_df.iloc[most_similar_indices].index.tolist()[::-1]

print(f'The 5 most similar titles to "{query_title}" are:')
print('\n'.join(most_similar_titles))
# Out:
# The 5 most similar titles to "A Goofy Movie" are:
# The Fox and the Hound
# The Muppet Movie
# The Great Muppet Caper
# Robin Hood
# The Great Mouse Detective

# %% [markdown]
# ## 6. Conclusion
# ---
# This project aims to build a recommendation system for movies and TV shows using several techniques. The system will use features such as title, description, genres, production countries, actors, and more to calculate similarity scores between movies or TV shows. The system will provide a list of similar movies or TV shows based on the input of a user. By evaluating the performance of the recommendation system, we will be able to determine how well the system is able to provide accurate recommendations to users.
